# %% [markdown]
# # TSSL Lab 4 - Recurrent Neural Networks
# In this lab we will explore different RNN models and training procedures for a problem in time series prediction.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10,6)  # Increase default size of plots

# %% [markdown]
# Set the random seed, for reproducibility

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## 1. Load and prepare the data
# We will build a model for predicting the number of [sunspots](https://en.wikipedia.org/wiki/Sunspot). We work with a data set that has been published on [Kaggle](https://www.kaggle.com/robervalt/sunspots), with the description:
#
# _Sunspots are temporary phenomena on the Sun's photosphere that appear as spots darker than the surrounding areas. They are regions of reduced surface temperature caused by concentrations of magnetic field flux that inhibit convection. Sunspots usually appear in pairs of opposite magnetic polarity. Their number varies according to the approximately 11-year solar cycle._
#
# The data consists of the monthly mean total sunspot number, from 1749-01-01 to 2017-08-31.

# %%
# Read the data
data=pandas.read_csv('Sunspots.csv',header=0)
dates = data['Date'].values
y = data['Monthly Mean Total Sunspot Number'].values
ndata=len(y)
print(f'Total number of data points: {ndata}')

# We define a train/test split, here with 70 % training data
ntrain = int(ndata*0.7)
ntest = ndata-ntrain
print(f'Number of training data points: {ntrain}')
# Out:
# Total number of data points: 3252
# Number of training data points: 2276

# %%
plt.plot(dates[:ntrain], y[:ntrain])
plt.plot(dates[ntrain:], y[ntrain:])
plt.xticks(range(0, ndata, 300), dates[::300], rotation = 90);  # Show only one tick every 25th year for clarity

# %% [markdown]
# There is a clear seasonality to the data, but the amplitude of the peaks very quite a lot. Also, we note that the data is nonnegative, which is natural since it consists of counts of sunspots. However, for simplicity we will not take this constraint into account in this lab assignment and allow ourselves to model the data using a Gaussian likelihood (i.e. using MSE as a loss function).

# %% [markdown]
# From the plot we see that the range of the data is roughly [0,400] so as a simple normalization we divide by the constant `MAX_VAL=400`.

# %%
MAX_VAL = 400
y = y/MAX_VAL

# %% [markdown]
# ## 2. Baseline methods
# Before constructing any sophosticated models using RNNs, let's consider two baseline methods,
#
# 1. The first baseline is a "naive" method which simply predicts $y_{t} = y_{t-1}$.
# 2. The second baseline is an AR($p$) model (based on the implementation used for lab 1).
#
# We evaluate the performance of these method in terms of mean-squared-error and mean-absolute-error, to compare the more advanced models with later on.

# %%
def evalutate_performance(y_pred, y, split_time, name=None):
    """This function evaluates and prints the MSE and MAE of the prediction.
    
    Parameters
    ----------
    y_pred : ndarrary
        Array of size (n,) with predictions.
    y : ndarray
        Array of size (n,) with target values.
    split_time : int
        The leading number of elements in y_pred and y that belong to the training data set.
        The remaining elements, i.e. y_pred[split_time:] and y[split_time:] are treated as test data.
    """
    
    # Compute error in prediction
    resid = y - y_pred
    
    # We evaluate the MSE and MAE in the original scale of the data, i.e. we add back MAX_VAL
    train_mse = np.mean(resid[:split_time]**2)*MAX_VAL**2    
    test_mse = np.mean(resid[split_time:]**2)*MAX_VAL**2
    train_mae = np.mean(np.abs(resid[:split_time]))*MAX_VAL
    test_mae = np.mean(np.abs(resid[split_time:]))*MAX_VAL
    
    # Print
    print(f'Model {name}\n  Training MSE: {train_mse:.4f},   MAE: {train_mae:.4f}\n  Testing MSE:  {test_mse:.4f},   MAE: {test_mae:.4f}')

# %% [markdown]
# **Q1:** Implement the naive baseline method which predicts according to $\hat y_{t|t-1} = y_{t-1}$. Since the previous value is needed for the prediction we do not get a prediction at $t=1$. Hence, we evaluate the method by predicting values at $t=2, \dots, n$ (cf. an AR($p$) model where we start predicting at $t=p+1$).

# %%
# Store the predictions in an array of length ndata-1. Note that there is a shift in the indices
# between the prediction and the observation sequence, since there is no prediction available for the first observation.
# Specifically, y_pred_naive[t] is a prediction of y[t+1], so the first element of y_pred_naive is a prediction of the
# second element of y, and so on. We will use the same "bookeeping convention" throughout the lab, so it is important that
# you understand it!
y_pred_naive = y[:ndata-1]

evalutate_performance(y_pred_naive,  # Predictions
                      y[1:],         # Correspondsing target values
                      ntrain-1,      # Number of leading elements in the input arrays corrsponding to training data points
                      name='Naive')
# Out:
# Model Naive
#   Training MSE: 776.5437,   MAE: 19.3285
#   Testing MSE:  708.6360,   MAE: 19.2256

# %% [markdown]
# Next, we consider a slightly more advanced baseline method, namely an AR($p$) model.

# %%
# We import two functions that were written as part of lab 1
from tssltools_lab4 import fit_ar, predict_ar_1step

p=30  # Order of the AR model (set by a few manual trials)
ar_coef = fit_ar(y[:ntrain], p)  # Fit the model to the training data

# Predict. Note that y contains both training and validation data,
# and the prediction is for the values y_{p+1}, ..., y_{n}.
y_pred_ar = predict_ar_1step(ar_coef, y)

# %%
evalutate_performance(y_pred_ar,  # The prediction array is of length n-p
                      y[p:],      # Corresponding target values
                      ntrain-p,   # Number of leading elements in the input arrays corrsponding to training data points
                      name='AR')
# Out:
# Model AR
#   Training MSE: 603.8656,   MAE: 17.3420
#   Testing MSE:  590.3732,   MAE: 17.6221

# %% [markdown]
# ## 3. Simple RNN
# We will now construct a model based on a recurrent neural network. We will initially use the `SimpleRNN` class from _Keras_, which correspond to the basic Jordan-Elman network presented in the lectures.

# %% [markdown]
# **Q2:** Assume that we construct an "RNN cell" using the call `layers.SimpleRNN(units = d, return_sequences=True)`. Now, assume that an array `X` with the dimensions `[Q,M,P]` is fed as the input to the above object. We know that `X` contains a set of sequences (time series) with equal lengths. Specify which of the symbols ${Q,M,P}$ that corresponds to each of the items below:
# - The length of the sequences (number of time steps)
# - The number of features (at each time step), i.e. the dimension of each time series
# - The number of sequences
#
# Furthermore, specify the values of ${Q,M,P}$ for the data at hand (treated as a single time series).
#
# _Hint:_ Read the documentation for [SimpleRNN](https://www.tensorflow.org/api_docs/python/tf/keras/layers/SimpleRNN) to find the answer.

# %% [markdown]
# **A2:**

# %% [markdown]
# **Q3:** Continuing the question above, answer the following:
#
# - What is the meaning of setting `units = d`?
# - Assume that we pass a single time series of length $n$ as input to the layer. Then what is the dimension of the _output_?
# - If we would had set the parameter `return_sequences=False` when constructing the layer, then what would be the answer to the previous question?

# %%
n = 10
inputs = np.random.random([1, n, 8]).astype(np.float32)
simple_rnn = tf.keras.layers.SimpleRNN(4 ,  return_sequences=True)

output = simple_rnn(inputs)  # The output has shape `[32, 4]`.

output.shape
# Out:
# TensorShape([1, 10, 4])

# %% [markdown]
# **A3:**

# %% [markdown]
# In _Keras_, each layer is created separately and are then joined by a `Sequential` object. It is very easy to construct stacked models in this way. The code below corresponds to a simple Jordan-Elman Network on the form,
#
# \begin{align*}
# 	\mathbf{h}_{t} &= \sigma( W\mathbf{h}_{t-1} + U y_{t-1} + b ), \\
# 	\hat y_{t|t-1} &= C \mathbf{h_t} + c,
# \end{align*}
#
# _Note:_ It is not necessary to explicitly specify the input shape, since this can be inferred from the input on the first call. However, for the `summary` function to work we need to tell the model what the dimension of the input is so that it can infer the correct sizes of the involved matrices. Also note that in _Keras_ you can sometimes use `None` when some dimensions are not known in advance.

# %%
d = 10  # hidden state dimension

model0=keras.Sequential([
    # Simple RNN layer
    layers.SimpleRNN(units = d, input_shape=(None,1), return_sequences=True, activation='tanh'),
    # A linear output layer
    layers.Dense(units = 1, activation='linear')
])
    
# We store the initial weights in order to get an exact copy of the model when trying different training procedures    
model0.summary()
init_weights = model0.get_weights().copy()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, None, 10)          120
#
#  dense (Dense)               (None, None, 1)           11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Q4:** From the model summary we can see the number of paramters associated with each layer. Relate these numbers to the dimensions of the weight matrices and bias vectors $\{W, U, b, C, c\}$ in the mathematical model definition above.

# %% [markdown]
# **A4:**

# %% [markdown]
# ## 4. Training the RNN model
# In this section we will consider a few different ways of handling the data when training the simple RNN model constructed above. As a first step, however, we construct explicit input and target (output) arrays for the training and test data, which will simplify the calls to the training procedures below.

# %% [markdown]
# The task that we consider in this lab is one-step prediction, i.e. at each time step we compute a prediction $\hat y_{t|t-1} \approx y_t$ which depend on the previous observations $y_{1:t-1}$. However, when working with RNNs, the information contained in previous observations is aggregated in the _state_ of the RNN, and we will only use $y_{t-1}$ as the _explicit input_ at time step $t$.
#
# Furthermore, when addressing a problem of time series prediction it is often a good idea to introduce an explicit skip connection from the input $y_{t-1}$ to the prediction $\hat y_{t|t-1}$. Equivalently, we can _define the target value_ at time step $t$ to be the residual $\tilde y_t := y_t - y_{t-1}$. Indeed, if the model can predict the value of the residual, then we can simply add back $y_{t-1}$ to get a prediction of $y_t$.

# %% [markdown]
# Taking this into consideration, we define explicit input and output arrays as shifted versions of the data series $y_{1:n}$.

# %%
# Training data
x_train = y[:ntrain-1]  # Input is denoted by x, training inputs are x[0]=y[0], ..., x[ntrain-1]=y[ntrain-1]
yt_train = y[1:ntrain] - x_train  # Output is denoted by yt, training outputs are yt[0]=y[1]-y[0], ..., yt[ntrain-1] = y[ntrain]-y[ntrain-1]

# Test data
x_test = y[ntrain-1:-1]  # Test inputs are x_test[0] = y[ntrain-1], ..., x_test[ntest] = y[n-1]
yt_test = y[ntrain:] - x_test  # Test outputs are yt_test[0] = y[ntrain]-y[ntrain-1], ..., yt_test[ntest] = y[n]-y[n-1] 

# Reshape the data
x_train = x_train.reshape((1,ntrain-1,1))
yt_train = yt_train.reshape((1,ntrain-1,1))
x_test = x_test.reshape((1,ntest,1))
yt_test = yt_test.reshape((1,ntest,1))

# %% [markdown]
# ### Option 1. Process all data in each gradient computation ("do nothing")
# The first option is to process all data at each iteration of the gradient descent method.

# %%
model1 = keras.models.clone_model(model0)  # This creates a new instance of the same model
model1.set_weights(init_weights)  # We set the initial weights to be the same for all models

# %% [markdown]
# **Q5:** What should we set the _batch size_ to, in order to compute the gradient based on the complete training data sequnce at each iteration? Complete the code below!
#
# _Note:_ You can set `verbose=1` if you want to monitor the training progress, but if you do, please **clear the output of the cell** before generating a pdf with your solutions, so that we don't get multiple pages with training errors in the submitted reports.

# %%
model1.compile(loss='mse', optimizer='rmsprop', metrics=['mse'])
history = model1.fit(x_train, yt_train,
                     epochs = 200,
                     batch_size = ntrain-1,
                     verbose = 1, 
                     validation_data = (x_test, yt_test))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.0641 - mse: 0.0641 - val_loss: 0.0348 - val_mse: 0.0348
# Epoch 2/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0260 - mse: 0.0260 - val_loss: 0.0206 - val_mse: 0.0206
# Epoch 3/200
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 4/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 5/200
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 6/200
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 7/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 8/200
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 9/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 10/200
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 11/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 12/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 13/200
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 14/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 15/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 16/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 17/200
# 1/1 [==============================] - 0s 258ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 18/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 19/200
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 20/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 21/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 22/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 23/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 24/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 25/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 26/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 27/200
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 28/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 29/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 30/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 31/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 32/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 33/200
# 1/1 [==============================] - 0s 314ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 34/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 35/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 36/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 37/200
# 1/1 [==============================] - 0s 330ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 38/200
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 39/200
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 40/200
# 1/1 [==============================] - 0s 351ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 41/200
# 1/1 [==============================] - 0s 305ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 42/200
# 1/1 [==============================] - 0s 325ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 43/200
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 44/200
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 45/200
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 46/200
# 1/1 [==============================] - 0s 258ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 47/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 48/200
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 49/200
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 50/200
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 51/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 52/200
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 53/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 54/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 55/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 56/200
# 1/1 [==============================] - 0s 298ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 57/200
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 58/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 59/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 60/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 61/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 62/200
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 63/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 64/200
# 1/1 [==============================] - 0s 298ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 65/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 66/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 67/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 68/200
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 69/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 70/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 71/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 72/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 73/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 74/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 75/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 76/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 77/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 78/200
# 1/1 [==============================] - 0s 311ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 79/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 80/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 81/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 82/200
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 83/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 84/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 85/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 86/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 87/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 88/200
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 89/200
# 1/1 [==============================] - 0s 305ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 90/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 91/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 92/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 93/200
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 94/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 95/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 96/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 97/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 98/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 99/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 100/200
# 1/1 [==============================] - 0s 309ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 101/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 102/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 103/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 104/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 105/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 106/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 107/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 108/200
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 109/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 110/200
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 111/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 112/200
# 1/1 [==============================] - 0s 328ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 113/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 114/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 115/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 116/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 117/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 118/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 119/200
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 120/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 121/200
# 1/1 [==============================] - 0s 322ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 122/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 123/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 124/200
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 125/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 126/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 127/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 128/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 129/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 130/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 131/200
# 1/1 [==============================] - 0s 312ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 132/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 133/200
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 134/200
# 1/1 [==============================] - 0s 309ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 135/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 136/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 137/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 138/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 139/200
# 1/1 [==============================] - 0s 311ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 140/200
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 141/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 142/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 143/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 144/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 145/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 146/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 147/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 148/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 149/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 150/200
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 151/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 152/200
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 153/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 154/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 155/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 156/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 157/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 158/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 159/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 160/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 161/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 162/200
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 163/200
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 164/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 165/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 166/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 167/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 168/200
# 1/1 [==============================] - 0s 297ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 169/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 170/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 171/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 172/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 173/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 174/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 175/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 176/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 177/200
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 178/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 179/200
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 180/200
# 1/1 [==============================] - 0s 320ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 181/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 182/200
# 1/1 [==============================] - 0s 326ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 183/200
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 184/200
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 185/200
# 1/1 [==============================] - 0s 323ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 186/200
# 1/1 [==============================] - 0s 332ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 187/200
# 1/1 [==============================] - 0s 322ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 188/200
# 1/1 [==============================] - 0s 311ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 189/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 190/200
# 1/1 [==============================] - 0s 356ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 191/200
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 192/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 193/200
# 1/1 [==============================] - 0s 311ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 194/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 195/200
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 196/200
# 1/1 [==============================] - 0s 387ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 197/200
# 1/1 [==============================] - 0s 346ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 198/200
# 1/1 [==============================] - 0s 305ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 199/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 200/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040

# %% [markdown]
# We plot the training and test error vs the iteration (epoch) number, using a helper function from the `tssltools_lab4` module.

# %%
from tssltools_lab4 import plot_history
start_at = 10  # Skip the first few epochs for clarity
plot_history(history, start_at)

# %% [markdown]
# **Q6:** Finally we compute the predictions of $\{y_t\}$ for both the training and test data uning the model's `predict` function. Complete the code below to compute the predictions.
#
# _Hint:_ You need to reshape the data when passing it to the `predict` to comply with the input shape used in _Keras_ (cf. above).
#
# _Hint:_ Since the model is trained on the residuals $\tilde y_t$, don't forget to add back $y_{t-1}$ when predicting $y_t$. However, make sure that you dont "cheat" by using a non-causal predictor (i.e. using $y_t$ when predicting $y_t$)!

# %%
# Predict on all data using the final model.
y_data = y[:ndata-1]
y_data = y_data.reshape((1,ndata-1,1))
# We predict using y_1,...,y_{n-1} as inputs, resulting in predictions of the values y_2, ..., y_n.
# That is, y_pred1 should be an (n-1,) array where element y_pred[t] is based only on values y[:t]
y_pred1 = model1.predict( y[:-1].reshape(1, ndata-1, 1)).flatten() + y[:-1]
# Out:
# 1/1 [==============================] - 0s 234ms/step

# %% [markdown]
# Using the prediction computed above we can plot them and evaluate the performance of the model in terms of MSE and MAE.

# %%
def plot_prediction(y_pred):
    # Plot prediction on test data
    plt.plot(dates[ntrain:], y[ntrain:])
    plt.plot(dates[ntrain:], y_pred[ntrain-1:])
    plt.xticks(range(0, ntest, 300), dates[ntrain::300], rotation = 90);  # Show only one tick every 25th year for clarity
    plt.legend(['Data','Prediction'])
    plt.title('Predictions on test data')

# %%
# Plot prediction
plot_prediction(y_pred1)
    
# Evaluate MSE and MAE (both training and test data)
evalutate_performance(y_pred1, y[1:], ntrain-1, name='Simple RNN, "do nothing"')
# Out:
# Model Simple RNN, "do nothing"
#   Training MSE: 653.0346,   MAE: 17.9898
#   Testing MSE:  634.0189,   MAE: 17.8591

# %% [markdown]
# ### Option 2. Random windowing
# Instead of using all the training data when computing the gradient for the numerical optimizer, we can speed it up by restricting the gradient computation to a smaller window of consecutive time steps. Here, we sample a random window within the traing data and "pretend" that this window is independent from the observations outside the window. Specifically, when processing the observations within each window the hidden state of the RNN is initialized to zero at the first time point in the window.
#
# To implement this method in Python, we will make use of a _generator function_. A generator is a function that can be paused, return an intermediate value, and then resumed to continue its execution. An intermediate return value is produces using the `yield` keyword.
#
# Generators are used in _Keras_ to implement inifinite loops that feed the training procedure with training data. Specifically, the `yield` statement of the generator should return a pair `x, y` with inputs and corresponding targets from the training data. Each epoch of the training procedure will then call the generator for a total of `steps_per_epoch` such `yield` statements.

# %%
def generator_train(window_size):    
    while True:
        """The upper value is excluded in randint, so the maximum value that we can get is tt = ntrain-window_size-1.
        Hence, the maximum end point of a window is ntrain-1, in agreement with the fact that the size of input/output is ntrain-1
        when working with one-step-ahead prediction.""" 
        start_of_window = np.random.randint(0, ntrain - window_size)  # First time index of window (inclusive)
        end_of_window = start_of_window + window_size  # Last time index of window (exclusive, i.e. this is really the first index _after_ the window)
        yield x_train[:,start_of_window:end_of_window,:], yt_train[:,start_of_window:end_of_window,:]

# %%
model2 = keras.models.clone_model(model0)  # This creates a new instance of the same model
model2.set_weights(init_weights)  # We set the initial weights to be the same for all models

# %% [markdown]
# **Q7:** Assume that we process a window of observations of length `window_size` at each iteration. Then, how many gradient steps per epoch can we afford, for computational cost per epoch to be comparable to the method considered in Option 1? Set the `steps_per_epoch` parameter of the fitting function based on your answer.

# %%
window_size = 100
model2.compile(loss='mse', optimizer='rmsprop', metrics=['mse'])
history = model2.fit(generator_train(window_size),
           epochs = 200,
           verbose = 1, 
           steps_per_epoch = int(ntrain//window_size) , 
           validation_data = (x_test, yt_test))
# Out:
# Epoch 1/200
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 2/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 3/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 4/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 5/200
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 6/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 7/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 8/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 9/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 10/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 11/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 12/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 13/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 14/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 15/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 16/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 17/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 18/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 19/200
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 20/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 21/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 22/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 23/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 24/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 25/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 26/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 27/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 28/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 29/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 30/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 31/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 32/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 33/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 34/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 35/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 36/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 37/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 38/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 39/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 40/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 41/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 42/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 43/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 44/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 45/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 46/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 47/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 48/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 49/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 50/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 51/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 52/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 53/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 54/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 55/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 56/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 57/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 58/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 59/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 60/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 61/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 62/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 63/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 64/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 65/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 66/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 67/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 68/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 69/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 70/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 71/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 72/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 73/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 74/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 75/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 76/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 77/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 78/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 79/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 80/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 81/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 82/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 83/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 84/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 85/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 86/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 87/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 88/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 89/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 90/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 91/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 92/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 93/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 94/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 95/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 96/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 97/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 98/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 99/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 100/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 101/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 102/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 103/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 104/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 105/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 106/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 107/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 108/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 109/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 110/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 111/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 112/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 113/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 114/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 115/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 116/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 117/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 118/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 119/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 120/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 121/200
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 122/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 123/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 124/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 125/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 126/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 127/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 128/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 129/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 130/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 131/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 132/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 133/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 134/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 135/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 136/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 137/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 138/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 139/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 140/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 141/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 142/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 143/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 144/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 145/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 146/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 147/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 148/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 149/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 150/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 151/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 152/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 153/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 154/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 155/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 156/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 157/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 158/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 159/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 160/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 161/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 162/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 163/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 164/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 165/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 166/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 167/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 168/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 169/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 170/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 171/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 172/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 173/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 174/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 175/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 176/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 177/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 178/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 179/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 180/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 181/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 182/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 183/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 184/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 185/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 186/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 187/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 188/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 189/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 190/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 191/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 192/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 193/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 194/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 195/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 196/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 197/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 198/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 199/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 200/200
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0036 - val_mse: 0.0036

# %% [markdown]
# Similarly to above we plot the error curves vs the iteration (epoch) number.

# %%
plot_history(history, start_at)

# %% [markdown]
# **Q8:** Comparing this error plot to the one you got for training Option 1, can you see any _qualitative_ differences? Explain the reason for the difference.

# %% [markdown]
# **A8:**

# %% [markdown]
# **Q9:** Compute a prediction for all values of $\{y_2, \dots, y_n\}$ analogously to **Q6**.

# %%
# Predict on all data using the final model.
y_data = y[:ndata-1]
y_data = y_data.reshape((1,ndata-1,1))
# We predict using y_1,...,y_{n-1} as inputs, resulting in predictions of the values y_2, ..., y_n.
# That is, y_pred1 should be an (n-1,) array where element y_pred[t] is based only on values y[:t]
y_pred2 = model1.predict( y[:-1].reshape(1, ndata-1, 1)).flatten() + y[:-1]
# Out:
# 1/1 [==============================] - 0s 121ms/step

# %%
# Plot prediction on test data
plot_prediction(y_pred2)
    
# Evaluate MSE and MAE (both training and test data)
evalutate_performance(y_pred2, y[1:], ntrain-1, name='Simple RNN, windowing')
# Out:
# Model Simple RNN, windowing
#   Training MSE: 653.0346,   MAE: 17.9898
#   Testing MSE:  634.0189,   MAE: 17.8591

# %% [markdown]
# ### Option 3. Sequential windowing with stateful training
# As a final option we consider a model aimed at better respecting the temporal dependencies between consequtive windows. This is based on "statefulness" which simply means that the RNN remembers its hidden state between calls. That is, if model is in stateful mode and is used to process two sequences of inputs after each other, then the final state from the first sequence is used as the initial state for the second sequence.

# %%
# To enable stateful training, we need to create model where we set stateful=True in the RNN layer
model3=keras.Sequential([
    # Simple RNN layer with stateful=True
    layers.SimpleRNN(units = d, batch_input_shape=(1,None,1), return_sequences=True, stateful=True, activation='tanh'),
    # A linear output layer
    layers.Dense(1, activation='linear')
])
model3.set_weights(init_weights)

# %% [markdown]
# **Q10:** When working with stateful training we need to make some adjustments to the training data generator.
#
# 1. First, the RNN model doesn't keep track of the actual time indices of the different windows that it is fed. Hence, if we feed the model randomly selected windows, it will still treat them as if they were consecutive, and retain the state from one window to the next. To avoid this, we therefore need to make sure that the generator outputs windows of training data that are indeed consecutive (and not ranomdly selected as above).
#
# 2. When training the model we will process the whole training data multiple times (i.e. we train for multiple epochs). However, if we have statefulness _between epochs_ this would effectively result in a "circular dependence", where the final state at time step $t = n_{\text{train}}$ would be used as the initial state at time $t=1$. To avoid this, we can manually reset the state of the model by calling `model.reset_states()`.
#
# Taking this two points into consideration, complete the code for the stateful data generator below.

# %%
def generator_train_stateful(window_size, model):
    """In addition to the window_size, the generator also takes the model as input so
    that we can reset the RNN states at appropiate intervals."""
    
    # Compute the total number of windows of length window_size that we need to cover all the training data.
    #  Note 1. The length of x_train (and yt_train) is ntrain-1 since we work with 1-step prediction.
    #  Note 2. The final window could be smaller than window_size, if (ntrain-1) is not evenly divisable by the window_size.    
    number_of_windows = int( (ntrain-1)//window_size )
    
    while True:
        for i in range(number_of_windows):
            # First time index of window (inclusive)
            start_of_window = i*window_size
            
            # Last time index of window (exclusive, i.e. this is the index to the first time step after the window)
            # Note 3. Python allows using end_of_window > ntrain-1, it will simply truncate the indexing at the final element of the array!
            end_of_window = (i+1)*window_size
            
            yield x_train[:,start_of_window:end_of_window,:], yt_train[:,start_of_window:end_of_window,:]
        model.reset_states()    
    """NOTE! In addition to replacing the ????? with the correct code, you need to move the line"""
        
    """to the correct place in the function definition above!"""

# %% [markdown]
# With the generator defined we can train the model.

# %%
window_size = 100
model3.compile(loss='mse', optimizer='rmsprop', metrics=['mse'])
history = model3.fit(generator_train_stateful(window_size, model3),
           epochs = 200,
           verbose = 1, 
           steps_per_epoch = ntrain//window_size, 
           validation_data = (x_test, yt_test))
# Out:
# Epoch 1/200
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 2/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 3/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 4/200
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 5/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 6/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 7/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 8/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 9/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 10/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 11/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 12/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 13/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 14/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 15/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 16/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 17/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 18/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 19/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 20/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 21/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 22/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 23/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 24/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 25/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 26/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 27/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 28/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 29/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 30/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 31/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 32/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 33/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 34/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 35/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 36/200
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 37/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 38/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 39/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 40/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 41/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 42/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 43/200
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 44/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 45/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 46/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 47/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 48/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 49/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 50/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 51/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 52/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 53/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 54/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 55/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 56/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 57/200
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 58/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 59/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 60/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 61/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 62/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 63/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 64/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 65/200
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 66/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 67/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 68/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 69/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 70/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 71/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 72/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 73/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 74/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 75/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 76/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 77/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 78/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 79/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 80/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 81/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 82/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 83/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 84/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 85/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 86/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 87/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 88/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 89/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 90/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 91/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 92/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 93/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 94/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 95/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 96/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 97/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 98/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 99/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 100/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 101/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 102/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 103/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 104/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 105/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 106/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 107/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 108/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 109/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 110/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 111/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 112/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 113/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 114/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 115/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 116/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 117/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 118/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 119/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 120/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 121/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 122/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 123/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 124/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 125/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 126/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 127/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 128/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 129/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 130/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 131/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 132/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 133/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 134/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 135/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 136/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 137/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 138/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 139/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 140/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 141/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 142/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 143/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 144/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 145/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 146/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 147/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 148/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 149/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 150/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 151/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 152/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 153/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 154/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 155/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 156/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 157/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 158/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 159/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 160/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 161/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 162/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 163/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 164/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 165/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 166/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 167/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 168/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 169/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 170/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 171/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 172/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 173/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 174/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 175/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 176/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 177/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 178/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 179/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 180/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 181/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 182/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 183/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 184/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 185/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 186/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 187/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 188/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 189/200
# 22/22 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 190/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 191/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 192/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 193/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 194/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 195/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 196/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 197/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 198/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 199/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 200/200
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0040 - val_mse: 0.0040

# %% [markdown]
# Similarly to above we plot the error curves vs the iteration (epoch) number.

# %%
plot_history(history, start_at)

# %% [markdown]
# **Q11:** Comparing this error plot to the one you got for training Options 1 and 2, can you see any _qualitative_ differences?
#
# _Optional:_ If you have a theory regarding the reason for the observed differences, feel free to explain!

# %% [markdown]
# **A11:**

# %% [markdown]
# **Q12:** Compute a prediction for all values of $\{y_2, \dots, y_n\}$ analogously to **Q6**.

# %%
# Predict on all data using the final model.
# We predict using y_1,...,y_{n-1} as inputs, resulting in predictions of the values y_2, ..., y_n
y_pred3 = model3.predict( y[:-1].reshape(1, ndata-1, 1)).flatten() + y[:-1]
# Out:
# 1/1 [==============================] - 0s 308ms/step

# %%
# Plot prediction on test data
plot_prediction(y_pred3)
    
# Evaluate MSE and MAE (both training and test data)
evalutate_performance(y_pred3, y[1:], ntrain-1, name='Simple RNN, windowing/stateful')
# Out:
# Model Simple RNN, windowing/stateful
#   Training MSE: 627.2475,   MAE: 17.6371
#   Testing MSE:  635.1697,   MAE: 17.8574

# %% [markdown]
# ## 5. Reflection
# **Q13:** Which model performed best? Did you manage to improve the prediction compared to the two baseline methods? Did the RNN models live up to your expectations? Why/why not? Please reflect on the lab using a few sentences.

# %% [markdown]
# **A13:**

# %% [markdown]
# ## 6. A more complex network (OPTIONAL)
# If you are interested, feel free to play around with more complex models and see if you can improve the predictive performance! It is very easy to build stacked models in _Keras_, see the example below.

# %%
# A stacked model with 3 layers of LSTM cells, two Dense layers with Relu activation and a final linear output layer
model4 = tf.keras.models.Sequential([
  tf.keras.layers.LSTM(64, batch_input_shape=(1,None,1), return_sequences=True, stateful=True),
  tf.keras.layers.LSTM(64, batch_input_shape=(1,None,1), return_sequences=True, stateful=True),
  tf.keras.layers.LSTM(64, batch_input_shape=(1,None,1), return_sequences=True, stateful=True),
  tf.keras.layers.Dense(32, activation="relu"),
  tf.keras.layers.Dense(16, activation="relu"),
  tf.keras.layers.Dense(1),
])

model4.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (1, None, 64)             16896
#
#  lstm_1 (LSTM)               (1, None, 64)             33024
#
#  lstm_2 (LSTM)               (1, None, 64)             33024
#
#  dense_2 (Dense)             (1, None, 32)             2080
#
#  dense_3 (Dense)             (1, None, 16)             528
#
#  dense_4 (Dense)             (1, None, 1)              17
#
# =================================================================
# Total params: 85,569
# Trainable params: 85,569
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We can store the best model in a file, so that we can load it after analyisng the training procedure.

# %%
checkpoint_filepath = './'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    save_best_only=True)  # Save only the best model, determined by the validation loss

# %% [markdown]
# Train the model

# %%
window_size = 100
model4.compile(loss='mse', optimizer='rmsprop', metrics=['mse'])
history = model4.fit(generator_train_stateful(window_size, model4),
           epochs = 200,
           verbose = 1, 
           steps_per_epoch = ntrain//window_size, 
           validation_data = (x_test, yt_test),
           callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/200
# 22/22 [==============================] - 5s 86ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 2/200
# 22/22 [==============================] - 1s 48ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 3/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 4/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 5/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 6/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 7/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 8/200
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 9/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 10/200
# 22/22 [==============================] - 1s 66ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 11/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 12/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 13/200
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 14/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 15/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 16/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 17/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 18/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 19/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 20/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 21/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 22/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 23/200
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 24/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 25/200
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 26/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 27/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 28/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 29/200
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 30/200
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 31/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 32/200
# 22/22 [==============================] - 1s 48ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 33/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 34/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 35/200
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 36/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 37/200
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 38/200
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 39/200
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 40/200
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 41/200
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 42/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 43/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 44/200
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 45/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 46/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 47/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 48/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 49/200
# 22/22 [==============================] - 1s 61ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 50/200
# 22/22 [==============================] - 2s 92ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 51/200
# 22/22 [==============================] - 1s 65ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 52/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 53/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 54/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 55/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 56/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 57/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 58/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 59/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 60/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 61/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 62/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 63/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 64/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 65/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 66/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 67/200
# 22/22 [==============================] - 1s 64ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 68/200
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 69/200
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 70/200
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 71/200
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 72/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 73/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 74/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 75/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 76/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 77/200
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 78/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 79/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 80/200
# 22/22 [==============================] - 1s 61ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 81/200
# 22/22 [==============================] - 2s 67ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 82/200
# 22/22 [==============================] - 2s 71ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 83/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 84/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 85/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 86/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 87/200
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 88/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 89/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 90/200
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 91/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 92/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 93/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 94/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 95/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 96/200
# 22/22 [==============================] - 2s 72ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 97/200
# 22/22 [==============================] - 1s 69ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 98/200
# 22/22 [==============================] - 2s 82ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 99/200
# 22/22 [==============================] - 1s 65ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 100/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 101/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 102/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 103/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 104/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 105/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 106/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 107/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 108/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 109/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 110/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 111/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 112/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 113/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 114/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 115/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 116/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 117/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 118/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 119/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 120/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 121/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 122/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 123/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 124/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 125/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 126/200
# 22/22 [==============================] - 2s 74ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 127/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 128/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 129/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 130/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 131/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 132/200
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 133/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 134/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 135/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 136/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 137/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 138/200
# 22/22 [==============================] - 2s 89ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 139/200
# 22/22 [==============================] - 2s 95ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 140/200
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 141/200
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 142/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 143/200
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 144/200
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 145/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 146/200
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 147/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 148/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 149/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 150/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 151/200
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 152/200
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 153/200
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 154/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 155/200
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 156/200
# 22/22 [==============================] - 1s 69ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 157/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 158/200
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 159/200
# 22/22 [==============================] - 1s 61ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 160/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 161/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 162/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 163/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 164/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 165/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 166/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 167/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 168/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 169/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 170/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 171/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 172/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 173/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 174/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 175/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 176/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 177/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 178/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 179/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 180/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 181/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 182/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 183/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 184/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 185/200
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 186/200
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 187/200
# 22/22 [==============================] - 2s 97ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 188/200
# 22/22 [==============================] - 2s 82ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 189/200
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 190/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 191/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 192/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 193/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 194/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 195/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 196/200
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 197/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 198/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 199/200
# 22/22 [==============================] - 1s 53ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 200/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0053 - val_mse: 0.0053

# %%
plot_history(history, start_at)

# %% [markdown]
# **Q14 (optional):** Based on the training and test error plots, are there signs of over- or underfitting?

# %% [markdown]
# **A14:**

# %% [markdown]
# We load the best model from checkpoint.

# %%
model4.load_weights(checkpoint_filepath)

# %%
# Predict on all data using the final model.
# We predict using y_1,...,y_{n-1} as inputs, resulting in predictions of the values y_2, ..., y_n
y_pred4 = model4.predict( y_data ).flatten() + y[1:ndata]
# Out:
# 1/1 [==============================] - 1s 927ms/step

# %%
# Predict on all data using the final model.
# We predict using y_1,...,y_{n-1} as inputs, resulting in predictions of the values y_2, ..., y_n
y_pred4 = model4.predict(y[:-1].reshape(1, ndata-1, 1)).flatten() + y[:-1]
# Out:
# 1/1 [==============================] - 0s 196ms/step

# %%
# Plot prediction on test data
plot_prediction(y_pred4)
    
# Evaluate MSE and MAE (both training and test data)
evalutate_performance(y_pred4, y[1:], ntrain-1, name='Stacked RNN, windowing/stateful')
# Out:
# Model Stacked RNN, windowing/stateful
#   Training MSE: 598.7284,   MAE: 17.2336
#   Testing MSE:  600.0152,   MAE: 17.3907

# %%
# A stacked model with 3 layers of LSTM cells, two Dense layers with Relu activation and a final linear output layer
model = tf.keras.models.Sequential([
  tf.keras.layers.LSTM(64, batch_input_shape=(1,None,1), return_sequences=True, stateful=True),
  tf.keras.layers.LSTM(64, batch_input_shape=(1,None,1), return_sequences=True, stateful=True),
  tf.keras.layers.LSTM(64, batch_input_shape=(1,None,1), return_sequences=True, stateful=True),
  tf.keras.layers.Dense(32, activation="relu"),
  tf.keras.layers.Dense(16, activation="relu"),
  tf.keras.layers.Dense(1),
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (1, None, 64)             16896
#
#  lstm_1 (LSTM)               (1, None, 64)             33024
#
#  lstm_2 (LSTM)               (1, None, 64)             33024
#
#  dense (Dense)               (1, None, 32)             2080
#
#  dense_1 (Dense)             (1, None, 16)             528
#
#  dense_2 (Dense)             (1, None, 1)              17
#
# =================================================================
# Total params: 85,569
# Trainable params: 85,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Read the data
data=pandas.read_csv('Sunspots.csv',header=0)
dates = data['Date'].values
y = data['Monthly Mean Total Sunspot Number'].values
ndata=len(y)

# We define a train/test split, here with 70 % training data
ntrain = int(ndata*0.7)
print(f'Total number of data points: {ndata}')
print(f'Number of training data points: {ntrain}')

MAX_VAL = 400
y = y/MAX_VAL
# Out:
# Total number of data points: 3252
# Number of training data points: 2276

# %%
model.load_weights('./')

# %%
ntest = ndata - ntrain

model.reset_states() # Not really needed since this is the first call, but still

y_pred = model.predict(y[:-1].reshape(1, ndata-1, 1)).flatten() + y[:-1]
# Out:
# 1/1 [==============================] - 1s 980ms/step

# %%
plt.plot(dates[ntrain:], y[ntrain:]) # Test data
plt.xticks(range(0, ntest, 120), dates[ntrain::120], rotation = 90);  # Show only one tick every 10th year for clarity
plt.plot(dates[ntrain:], y_pred[ntrain-1:]) # We shift by one since the first prediction is for time 2
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
